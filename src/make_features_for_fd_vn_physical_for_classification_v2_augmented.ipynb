# %%
import csv
import json
import numpy as np
import pandas as pd

# %%
augmented_data_path = '/nfs/research/regan/src/coling2020-code/data/augmented_with_ccs_rq13_v3.csv'

df = pd.read_csv(augmented_data_path)

df.head()
# Out:
#    Unnamed: 0     pk                                                 cc  \
# 0           0  664.0  [{'text': 'cart', 'q_value': 'INTL', 'index': ...
# 1           1  665.0  [{'text': 'rope', 'q_value': '+MER', 'index': ...
# 2           2  666.0  [{'text': 'rope', 'q_value': '+MER', 'index': ...
# 3           3  667.0  [{'text': 'company', 'q_value': '+MER', 'index...
# 4           4  669.0  [{'text': 'computer', 'q_value': '+MER', 'inde...
#
#                                           sentence       syntax         fd1  \
# 0            The grocery cart hit against the wall  Sbj V PathP    Physical
# 1  That type of rope coiled easily around the post  Sbj V PathP  Autonomous
# 2                  The rope coiled around the post  Sbj V PathP  Autonomous
# 3          The company is wedging into new markets  Sbj V PathP  Autonomous
# 4       The computer connected well to the network  Sbj V PathP  Autonomous
#
#      fd2   fd3     verb  augmented  \
# 0  Force  none      hit          0
# 1  Place  none     coil          0
# 2  Place  none     coil          0
# 3  Place  none    wedge          0
# 4  Place  none  connect          0
#
#                                                  dep         silver_cc  \
# 0  [{'text': 'The', 'dep': 'det'}, {'text': 'groc...         cart wall
# 1  [{'text': 'That', 'dep': 'det'}, {'text': 'typ...         rope post
# 2  [{'text': 'The', 'dep': 'det'}, {'text': 'rope...         rope post
# 3  [{'text': 'The', 'dep': 'det'}, {'text': 'comp...   company markets
# 4  [{'text': 'The', 'dep': 'det'}, {'text': 'comp...  computer network
#
#             gold_cc
# 0         cart wall
# 1         rope post
# 2         rope post
# 3   company markets
# 4  computer network
